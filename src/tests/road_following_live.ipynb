# %% [markdown]
# # Road Following Live (with camera)

# %%
import torch
import sys
from torch2trt import TRTModule

model_trt = TRTModule()
model_trt.load_state_dict(torch.load('/home/jetson/github/tfg-amariscal/models/road_following_model_trt_3.pth'))
print("Model loaded")
# Out:
# Model loaded

# %% [markdown]
# Create the racecar class

# %%
from jetracer.my_racecar import MyRacecar
import Jetson.GPIO as GPIO
#from motorsJetson import Motors

# Left motors
ENA = 33
IN1 = 21
IN2 = 22

# Right motors
ENB = 32
IN3 = 26
IN4 = 24

# 50 Hz
FREQUENCY = 50

car = MyRacecar()
#GPIO.setmode(GPIO.BOARD)
#GPIO.setwarnings(False)

#motors = Motors(ENA, IN1, IN2, ENB, IN3, IN4, FREQUENCY)
print("Car loaded")
# Out:
# Car loaded

# %% [markdown]
# Create the camera class.

# %%
from jetcam.usb_camera import USBCamera

camera = USBCamera(width=224, height=224, capture_width=640, capture_height=480, capture_device=0)
print("Camera loaded")
# Out:
# Capture device is 0
# Camera loaded

# %%
import cv2
import ipywidgets
import threading

state_widget = ipywidgets.ToggleButtons(options=['On', 'Off'], description='Camera', value='On')
prediction_widget = ipywidgets.Image(format='jpeg', width=camera.width, height=camera.height)

live_execution_widget = ipywidgets.VBox([
    prediction_widget,
    state_widget
])
print("live_execution_widget loaded")
# Out:
# live_execution_widget loaded

# %% [markdown]
# Before letting your car go, let's prepare slide bars for gains and offset, so that you can adjust them during the runtime.

# %%
import traitlets
from IPython.display import display
from ipywidgets import Layout, Button, Box
import ipywidgets.widgets as widgets

network_output_slider = widgets.FloatSlider(description='Network Output', min=-1.0, max=1.0, value=0, step=0.01, orientation='horizontal', disabled=False, layout={'width': '400px'})
steering_gain_slider  = widgets.FloatSlider(description='Steering Gain', min=-10.0, max=10.0, value=1, step=1, orientation='horizontal', layout={'width': '300px'})
steering_bias_slider  = widgets.FloatSlider(description='Steering Bias', min=-0.5, max=0.5, value=0.0, step=0.01, orientation='horizontal', layout={'width': '300px'})
steering_value_slider = widgets.FloatSlider(description='Steering', min=-30.0, max=30.0, value=0, step=0.01, orientation='horizontal', disabled=False, layout={'width': '400px'})
throttle_slider = widgets.FloatSlider(description='Throttle', min=15, max=50, value=25, step=1, orientation='vertical')


steering_gain_link   = traitlets.link((steering_gain_slider, 'value'), (car, 'steering_gain'))
steering_offset_link = traitlets.link((steering_bias_slider, 'value'), (car, 'steering_offset'))
#steering_value_link  = traitlets.link((steering_value_slider, 'value'), (car, 'steering'))
#throttle_slider_link = traitlets.link((throttle_slider, 'value'), (car, 'throttle'))

display(
    widgets.HBox(
        [widgets.VBox([network_output_slider,
                       widgets.Label(value="X"),
                       steering_gain_slider,
                       widgets.Label(value="+"),
                       steering_bias_slider,
                       widgets.Label(value="||"), 
                       steering_value_slider], layout=Layout(
                                                    align_items='center'
                                                        )
                     ), 
         live_execution_widget,
         throttle_slider]
    )
)
# Out:
# HBox(children=(VBox(children=(FloatSlider(value=0.0, description='Network Output', layout=Layout(width='400px'…

# %% [markdown]
# Finally, execute the cell below to make the racecar move forward, steering the racecar based on the x value of the apex.
#
# Here are some tips,
#
# * If the car wobbles left and right,  lower the steering gain
# * If the car misses turns,  raise the steering gain
# * If the car tends right, make the steering bias more negative (in small increments like -0.05)
# * If the car tends left, make the steering bias more postive (in small increments +0.05)

# %%
from utils import preprocess
from jetcam.utils import bgr8_to_jpeg

def update(change):
    global blocked_slider, robot
    new_image = change['new'] 
    
    image = preprocess(new_image).half()
    output = model_trt(image).detach().cpu().numpy().flatten()
    x = float(output[0])
    y = float(output[0])
    
    network_output_slider.value = x
    steering = x * steering_gain_slider.value + steering_bias_slider.value
    
    #if(steering<-1.0):
     #   steering_value_slider.value = -1.0
    #elif(steering>1.0):
    #    steering_value_slider.value = 1.0
    #else:
    steering_value_slider.value = steering 
    car._on_steering(steering)
    car._on_throttle(throttle_slider.value)
    print("Thottle value: " + str(throttle_slider.value))
    
    if(state_widget.value == 'On'):
        x = int(camera.width * (x / 2.0 + 0.5))
        y = int(camera.height * (y / 2.0 + 0.5))  
        prediction = new_image.copy()
        prediction = cv2.circle(prediction, (x, y), 8, (255, 0, 0), 3)
        prediction_widget.value = bgr8_to_jpeg(prediction)
        
update({'new': camera.value})  # we call the function once to initialize
# Out:
# Forward: -0.122314453125 Throttle: 0
# Thottle value: 25.0

# %%
camera.observe(update, names='value')

# %%
camera.running = True
# Out:
# Forward: 0.168212890625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.16748046875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1639404296875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1622314453125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.16162109375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.165771484375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.16552734375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1678466796875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1617431640625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1541748046875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.173828125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1640625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1607666015625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.161865234375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1583251953125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1588134765625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.156005859375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1597900390625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1622314453125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.15771484375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1651611328125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.162353515625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.161376953125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1617431640625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1630859375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1622314453125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.162841796875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1669921875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.164306640625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.16455078125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.166015625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1666259765625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.165771484375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1649169921875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1663818359375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1668701171875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1650390625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.164794921875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1646728515625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1630859375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.165283203125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.167236328125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.16845703125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.170166015625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.168212890625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1654052734375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1612548828125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.16552734375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1651611328125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.166259765625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.159912109375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1553955078125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1524658203125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.158935546875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1478271484375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.146728515625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1522216796875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.180908203125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.180419921875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.203857421875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2034912109375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2071533203125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1961669921875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2174072265625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2025146484375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.20263671875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.195556640625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2025146484375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.169189453125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1595458984375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1517333984375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.147216796875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.145751953125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.135009765625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1365966796875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1646728515625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1934814453125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1883544921875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1839599609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1773681640625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.195068359375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.19482421875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2076416015625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.192626953125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.19091796875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.193359375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1932373046875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1851806640625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.192138671875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.19775390625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1846923828125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.190673828125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.194091796875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.191650390625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.18505859375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.209716796875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.19873046875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.1978759765625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.205810546875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.20703125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.20751953125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2091064453125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2177734375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.220703125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.22412109375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2294921875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.227783203125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.22900390625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.230224609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.233154296875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.231201171875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.233642578125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.238525390625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.238037109375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.234375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.234375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.234130859375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.237548828125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.23974609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.239501953125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.239501953125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.239501953125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24169921875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2412109375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24365234375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.241455078125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2392578125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.243896484375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.25048828125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.251953125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.26171875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.261474609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.264892578125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.262939453125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.26611328125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.263916015625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.265625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.26318359375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2666015625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.262939453125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.262939453125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.263916015625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.261962890625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.26123046875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.262939453125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.260986328125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.259765625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2568359375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2548828125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2568359375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.257080078125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.253662109375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.25439453125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.251708984375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.25537109375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.25341796875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.252685546875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2548828125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.255615234375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.258544921875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.253662109375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.253173828125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.25048828125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.250732421875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.25 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.251708984375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.249755859375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.252685546875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2509765625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.25 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.25 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.248779296875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.249755859375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.247802734375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.250244140625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.248291015625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.247802734375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24658203125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.247314453125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24658203125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.246337890625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24560546875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.243408203125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2421875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2421875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.244384765625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2421875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.242431640625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24365234375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.238037109375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.240478515625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.234619140625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.237548828125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24169921875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2392578125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.240966796875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2412109375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.238525390625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.23681640625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.23779296875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.23583984375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.236083984375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.236083984375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2353515625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2353515625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.237060546875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.23974609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.236572265625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2353515625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.238037109375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.23876953125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.234130859375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.23974609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.23876953125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.240966796875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.239990234375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2412109375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.23876953125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.23974609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.239990234375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24462890625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2412109375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.244140625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.241943359375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2412109375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24658203125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2421875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.242919921875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2431640625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.243408203125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.241455078125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.244384765625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.244140625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.240478515625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.240478515625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.23828125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.241455078125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2412109375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.242919921875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.23974609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.241455078125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2421875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.23974609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.240478515625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.243896484375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.244873046875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.245361328125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24462890625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.243408203125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.244873046875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.248779296875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.245361328125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.245849609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.244140625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24462890625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.244384765625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.244873046875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2421875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.242919921875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.245361328125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2451171875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.246826171875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24462890625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.245849609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.245361328125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.245849609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.245361328125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.244140625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2431640625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24072265625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.245849609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24755859375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.246337890625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24755859375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24755859375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.248291015625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.245849609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.249755859375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.248291015625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24853515625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.248779296875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.251220703125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24951171875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.250244140625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24951171875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24658203125 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.248291015625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.250732421875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.250732421875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.248779296875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24951171875 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.248291015625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.248291015625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.248291015625 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.2490234375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0.24609375 Throttle: 25.0
# Thottle value: 25.0
# Forward: 0